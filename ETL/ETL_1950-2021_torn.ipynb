# %%
import pandas as pd

# %%
torn_data_load = "Project3.csv"

# %%
torn_df = pd.read_csv(torn_data_load)

# %%
torn_df
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 0           1  1950   1   3  1950-01-03  11:00:00   3  MO   29    1  ...
# 1           1  1950   1   3  1950-01-03  11:00:00   3  MO   29    1  ...
# 2           1  1950   1   3  1950-01-03  11:10:00   3  IL   17    1  ...
# 3           2  1950   1   3  1950-01-03  11:55:00   3  IL   17    2  ...
# 4           3  1950   1   3  1950-01-03  16:00:00   3  OH   39    1  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 66383  618537  2019  12  29  2019-12-29  16:03:00   3  MS   28    0  ...
# 66384  618538  2019  12  29  2019-12-29  16:13:00   3  MS   28    0  ...
# 66385  618539  2019  12  29  2019-12-29  16:32:00   3  MS   28    0  ...
# 66386  618540  2019  12  29  2019-12-29  17:13:00   3  MS   28    0  ...
# 66387  618541  2019  12  29  2019-12-29  18:50:00   3  AL    1    0  ...
#
#         len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# ...

# %%
torn_df.dtypes
# Out:
# om         int64
# yr         int64
# mo         int64
# dy         int64
# date      object
# time      object
# tz         int64
# st        object
# stf        int64
# stn        int64
# mag        int64
# inj        int64
# fat        int64
# loss     float64
# closs    float64
# slat     float64
# slon     float64
# elat     float64
# elon     float64
# len      float64
# wid        int64
# ns         int64
# sn         int64
# sg         int64
# f1         int64
# f2         int64
# f3         int64
# f4         int64
# fc         int64
# dtype: object

# %%
torn_df['date'] = pd.to_datetime(torn_df['date'])

# %%
torn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66388 entries, 0 to 66387
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   om      66388 non-null  int64
#  1   yr      66388 non-null  int64
#  2   mo      66388 non-null  int64
#  3   dy      66388 non-null  int64
#  4   date    66388 non-null  datetime64[ns]
#  5   time    66388 non-null  object
#  6   tz      66388 non-null  int64
#  7   st      66388 non-null  object
#  8   stf     66388 non-null  int64
#  9   stn     66388 non-null  int64
#  10  mag     66388 non-null  int64
#  11  inj     66388 non-null  int64
#  12  fat     66388 non-null  int64
#  13  loss    66388 non-null  float64
#  14  closs   66388 non-null  float64
#  15  slat    66388 non-null  float64
#  16  slon    66388 non-null  float64
#  17  elat    66388 non-null  float64
#  18  elon    66388 non-null  float64
#  19  len     66388 non-null  float64
#  20  wid     66388 non-null  int64
# ...

# %%
# Export ETL data for json
torn_df.to_json('all_tornadoes1950-2021.json', orient='records')

# %%
new_torn_df = torn_df[['yr', 'mag', 'inj', 'fat']]

# %%
new_torn_df
# Out:
#          yr  mag  inj  fat
# 0      1950    3    3    0
# 1      1950    3    3    0
# 2      1950    3    0    0
# 3      1950    3    3    0
# 4      1950    1    1    0
# ...     ...  ...  ...  ...
# 66383  2019    1    0    0
# 66384  2019    1    0    0
# 66385  2019    0    0    0
# 66386  2019    1    0    0
# 66387  2019    0    0    0
#
# [66388 rows x 4 columns]

# %%
torn_df[['yr', 'mag', 'inj', 'fat']] = torn_df[['yr', 'mag', 'inj', 'fat']].astype(str)

# %%
print(torn_df.dtypes)
# Out:
# om                int64
# yr               object
# mo                int64
# dy                int64
# date     datetime64[ns]
# time             object
# tz                int64
# st               object
# stf               int64
# stn               int64
# mag              object
# inj              object
# fat              object
# loss            float64
# closs           float64
# slat            float64
# slon            float64
# elat            float64
# elon            float64
# len             float64
# wid               int64
# ns                int64
# sn                int64
# sg                int64
# f1                int64
# f2                int64
# f3                int64
# f4                int64
# fc                int64
# dtype: object

# %%
# Export ETL data for CSV
new_torn_df.to_csv("YrMagInjFat_tornadoes.csv", index=False)

# %%
# Export ETL data for json
new_torn_df.to_json('YrMagInjFat_tornadoes.json', orient='records')

# %%
# torn_df['time'] = pd.to_datetime(torn_df['time'])
# torn_df['time'] = torn_df['time'].astype(str)
# new_torn_df = torn_df.rename(columns={'time': 'datetime_NotForUse'})
# new_torn_df['time'] = new_torn_df['datetime_NotForUse'].dt.time

# %%
# new_torn_df.head()

# %%
# new_torn_df.dtypes
